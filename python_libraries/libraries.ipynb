# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.load_dataset("titanic")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Load the Titanic dataset
sns.titanic = sns.load_dataset("titanic")
# Display the first few rows of the dataset
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
from tkinter import Tk, filedialog, Label
from PIL import Image, ImageTk

# Create the main window
root = Tk()
root.title("Image Viewer")

# Function to open and display image
def open_image():
    file_path = filedialog.askopenfilename(
        filetypes=[("Image files", "*.jpg *.jpeg *.png *.bmp *.gif")]
    )
    if file_path:
        img = Image.open(file_path)
        img = img.resize((300, 300))  # Resize for display
        img_tk = ImageTk.PhotoImage(img)
        label.config(image=img_tk)
        label.image = img_tk  # Keep a reference

# Add a label to display the image
label = Label(root)
label.pack()

# Open file dialog on start
open_image()

root.mainloop()

# %% [markdown]
# ## GRAPH PRACTICE

# %%
pip install pillow-heif
# Out:
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.6 MB 7.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.6 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.6 MB 3.0 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.6 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.6 MB 2.7 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.6 MB 2.2 MB/s eta 0:00:03
#    --------------- ------------------------ 3.4/8.6 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 3.4/8.6 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 4.5/8.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.7/8.6 MB 2.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.7/8.6 MB 2.2 MB/s eta 0:00:02
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

range = np.arange(5, 20, 0.2)
# Create a simple plot
print("Creating a plot...")
plt.plot(range, np.sin(range)) 
plt.title("Sine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
# Out:
# Creating a plot...

# %% [markdown]
# ## 3D GRAPH

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_title("3D Surface Plot")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some random 3D data
np.random.seed(0) # for reproducibility
n_points = 100
x_data = np.random.rand(n_points)
y_data = np.random.rand(n_points)
z_data = np.random.rand(n_points)
colors = np.random.rand(n_points) # for coloring points
sizes = 100 * np.random.rand(n_points) # for sizing points

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(x_data, y_data, z_data, c=colors, s=sizes, cmap='viridis', alpha=0.7)

# Add labels and title
ax.set_xlabel('A Axis')
ax.set_ylabel('B Axis')
ax.set_zlabel('C Axis')
ax.set_title('Scatter Plot Graph in 3D')

# Add a color bar
fig.colorbar(scatter, label='Color Intensity')

# Show the plot
plt.show()
